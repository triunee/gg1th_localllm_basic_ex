# %% [markdown]
# # GPU 테스트

# %%
import torch

print(f"PyTorch 버전: {torch.__version__}")
print(f"CUDA 사용 가능 여부: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA 버전: {torch.version.cuda}")
    print(f"GPU 개수: {torch.cuda.device_count()}")
    print(f"GPU 이름: {torch.cuda.get_device_name(0)}")
    print(f"현재 디바이스: {torch.cuda.current_device()}")
else:
    print("GPU를 사용할 수 없다. CPU로 실행된다.")
# Out:
# Running cells with 'local-llm-app2th (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/aiuser/gg1th_local_llm_app/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # VRAM 확인

# %%
import torch
print(f"{torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")

# %% [markdown]
# # faster-whisper GPU 테스트

# %%
from faster_whisper import WhisperModel

model = WhisperModel(
    "small",
    device="cuda",
    compute_type="float16"
)

print("faster-whisper CUDA 로딩 성공")
